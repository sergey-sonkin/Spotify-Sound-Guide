# %% [markdown]
# # Spotify Sound Guide by Sergey Sonkin
#
# The code below is broken up into steps for
# * Step 0: Deal with env and global variables, including the artist's spotify id
# * Step 1: Get artist's albums
# * Step 2: Filter out duplicate albums
# * Step 3: Get track information, engineer any new features
# * Step 4: Repeat steps 1-3 but for artist's singles (done separately from albums to avoid duplicates)
# * Step 5: Process features for recommendation
# * Step 6: Get a seed song
# * Step 7: Define our likeability metric
# * Step 8: Start recommending!

# %% [markdown]
# ## Step 0: Dealing with request variables

# %%
import os
import requests
import pandas as pd
import re
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

client_id = os.getenv("SPOTIFY_CLIENT_ID")
client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")

data = "grant_type=client_credentials&client_id=" \
        + client_id \
        + "&client_secret=" \
        + client_secret
header = {
    "Content-Type": "application/x-www-form-urlencoded"
}
response = requests.post("https://accounts.spotify.com/api/token",headers=header,data=data)
access_token = response.json()['access_token']
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}
BASE_URL = 'https://api.spotify.com/v1/'

## Some artist ids
global_artist_id = "6qqNVTkY8uBg9cP3Jd7DAH" ##Billie Eilish
global_artist_id = "6fWVd57NKTalqvmjRd2t8Z" ##24kGoldn
global_artist_id = "2tIP7SsRs7vjIcLrU85W8J" ##The Kid Laroi
global_artist_id = "7dGJo4pcD2V6oG8kP0tJRR" ##Eminem
global_artist_id = "6wWVKhxIU2cEi0K81v7HvP" ##Rammstein
global_artist_id = "2kRfqPViCqYdSGhYSM9R0Q" ##Madison Beer

# %% [markdown]
# ## Step 1: Start by getting just albums

# %%
def get_albums(type='album',artist_id=global_artist_id):
    album_list = []
    counter = 0 ## Need counter to deal with limit of 50 per page
    while(True):
        print(counter)
        r = requests.get(BASE_URL + 'artists/' + artist_id + '/albums', 
                        headers=headers, 
                        params={'market':'US', 'include_groups': type, 'limit': 50, 'offset': 50*counter})
        d = r.json()
        if len(d['items']) == 0:
            print("Done!")
            break
        album_list += d['items']
        counter += 1
    return album_list

album_list = get_albums('album')
# Out:
# 0
# 1
# Done!

# %% [markdown]
# ## Step 2: Filter out duplicate albums
#
# How do we pick which of the duplicates to use? We choose based on the following criteria in order
#
# 1. Most explicit
# 2. Most recently released
# 3. Most number of tracks

# %%
def filter_duplicates(album_list):
    ## Generating list of album names
    names = [(i,re.sub(r'\W+', '',album['name'].lower())) for i,album in enumerate(album_list)]
    ## Generating list of duplicates (doubles)
    viewed = {}
    doubles = []
    for (index,name) in names:
        if name in viewed:
            other_index = viewed[name]
            doubles.append((name,index,other_index))
        else:
            viewed[name] = index

    ## How do we pick which of the dupli
    ## For each duplicate album, find which one has the explicit songs
    for (name,index_1,index_2) in doubles:
        album_id_1 = album_list[index_1]['id']
        album_id_2 = album_list[index_2]['id']
        r1 = requests.get(BASE_URL+'albums/'+album_id_1+'/tracks',headers=headers)
        r2 = requests.get(BASE_URL+'albums/'+album_id_2+'/tracks',headers=headers)
        tracks1 = r1.json()['items']
        tracks2 = r2.json()['items']
        explicit_1 = tracks1[0]['explicit']
        explicit_2 = tracks2[0]['explicit']
        ## If one is explicit but not the other, take the explicit version
        if explicit_1 and not explicit_2:
            viewed[name] = index_1
        elif explicit_2 and not explicit_1:
            viewed[name] = index_2
        ## If they're the same explicitness, take the more recently released version
        else:
            album_rd_1 = album_list[index_1].get("release_date",-1)
            album_rd_2 = album_list[index_2].get("release_date",-1)
            if album_rd_1 > album_rd_2:
                viewed[name] = index_1
            elif album_rd_2 > album_rd_1:
                viewed[name] = index_2
            else:
            ## If they're release on the same date, take the one with more tracks
                album_tracks_1 = album_list[index_1].get("total_tracks",-1)
                album_tracks_2 = album_list[index_2].get("total_tracks",-1)
                if album_tracks_1 > album_tracks_2:
                    viewed[name] = index_1
                elif album_tracks_2 > album_tracks_1:
                    viewed[name] = index_2
                ## If they have the same number of tracks honestly I'm defeated just pick the first
                else:
                    viewed[name] = index_1
    filtered_album_ids = list(viewed.values())
    print("We removed " + str(len(album_list) - len(filtered_album_ids)) + " duplicates")
    return filtered_album_ids

filtered_album_ids = filter_duplicates(album_list)
# Out:
# We removed 0 duplicates

# %% [markdown]
# ## Step 3: Get track information
#
# The star of the show is Spotify's "Get Tracks' Audio Features" endpoint. Its documention can be found here https://developer.spotify.com/documentation/web-api/reference/get-several-audio-features

# %% [markdown]
# ### Step 3a: Initialize track information
#
# First we create our pandas table with the basic information about each track we have from our queries above.
#
# If we have duplicate tracks, we filter for them as we go.

# %%
track_info = pd.DataFrame(columns = ["album_name","track_name","release_date","popularity","duration_ms",
                                     "acousticness","danceability","energy","instrumentalness","key","liveness",
                                     "loudness","mode","speechiness","tempo","time_signature","valence"])
track_info[['mode', 'time_signature']] = track_info[['mode', 'time_signature']].astype('int8')

## We will store track ids in a list for use in Step 3b
track_names = set()

def get_new_tracks(album_list,filtered_album_ids):
    global track_info
    track_ids = []
    for album_id in filtered_album_ids:
        ## Get the album
        album = album_list[album_id]
        album_name = album["name"]
        album_release_date = album["release_date"]
        ## Get the tracks for that album
        id = album['id']
        r = requests.get(BASE_URL+'albums/'+id+'/tracks',headers=headers)
        tracks = r.json()['items']
        ## For each track, just get the track name and id and set some initial values
        for track in tracks:
            track_id = track['id']
            track_name = track['name']
            track_popularity = track.get('popularity',0.0) ## Default value of 0
            duration_ms = track.get('duration_ms',180000) ## Default value of 3 minutes
            if track_name not in track_names:
                ## Creating new DF with desired column names
                new_track_dict = {"album_name":album_name,
                                  "track_name":track_name,
                                  "release_date":pd.to_datetime(album_release_date),
                                  "popularity":track_popularity,
                                  "duration_ms":duration_ms,
                                  "acousticness":0.0,
                                  "danceability":0.0,
                                  "energy":0.0,
                                  "instrumentalness":0.0,
                                  "key":0.0,
                                  "liveness":0.0,
                                  "loudness":0.0,
                                  "mode":0,
                                  "speechiness":0.0,
                                  "tempo":0.0,
                                  "time_signature":0,
                                  "valence":0.0}
                new_track_row = pd.DataFrame([new_track_dict],index=[track_id])
                ## Append to track_info, track_ids, and track_names
                track_info = track_info.append(new_track_row)
                track_ids.append(track_id)
                track_names.add(track_name)
            else:
                print("We have a duplicate track name: " + track_name)
    return track_ids

track_ids = get_new_tracks(album_list,filtered_album_ids)

# %% [markdown]
# ### Step 3b: Get song details
#
# Now for all of the (unique) tracks from 3a, we ask Spotify for its song features.
#
# Every once in a while Spotify just doesn't have any song features so we drop the song completely. It's not helpful to us if we don't know anything about it, and it happens so rarely that it's not a concern for the usability of this project.

# %%
special_features = ["acousticness","danceability","energy","instrumentalness","key","liveness",
                    "loudness","mode","speechiness","tempo","time_signature","valence"]
def get_features(track_ids,track_info):
    ## Break our song IDs into 100 song batches
    l = len(track_ids)
    width = 100
    iters = (l // width) + 1
    for ii in range(iters):
        ## Get these 100 songs intro a string
        track_id_subset = track_ids[width*ii:width*ii+width]
        tracks_string = (",").join(track_id_subset)
        ## Get the request with this data
        r = requests.get(BASE_URL + 'audio-features/',headers=headers,
                        params={'ids':tracks_string})
        audio_features = r.json()['audio_features']
        ## We got the audio features, now extract as much as possible
        for jj,audio_feature in enumerate(audio_features):
            track_id = track_id_subset[jj]
            try:
                for f in special_features:
                    track_info.loc[track_id,f] = audio_feature[f]
            except:
                track_id = jj + width*ii
                print("We have an issue with track id " + str(track_id) + " " + str(track_ids[track_id]))
                track_info = track_info.drop(track_ids[track_id])


get_features(track_ids,track_info)

# %%
track_info
# Out:
#                             album_name                       track_name  \
# 0lhDiOviH4xmzyYeOsn01M    Life Support                    The Beginning
# 4y3g40TWe7fCWCayJZuGvw    Life Support                  Good In Goodbye
# 5AEJyckUMzLqIyBxZNmGFW    Life Support                          Default
# 2Txj791OlOaNSMpps0gz5K    Life Support          Follow The White Rabbit
# 6sRmaXQZo0EK2woVn2COxM    Life Support                     Effortlessly
# 6mstsFlnLZidRE8K3JGtV7    Life Support           Stay Numb And Carry On
# 4a1RWaG4BTkifgMSx3rpf3    Life Support                             Blue
# 3Fsr7IhlNBZ1wV3QaJB5dv    Life Support                        Interlude
# 5QlMftmj7rFwhHoClCQLTP    Life Support                         Homesick
# 5UY8jf31X2hJkiAualFTyh    Life Support                          Selfish
# 4wz7R8N7gYgjhZuoMQkSve    Life Support                       Sour Times
# 6XiqdnMk2LLbmybmyx30jD    Life Support                          BOYSHIT
# 1X4ZkhlRRohkV33cITaJYs    Life Support                             Baby
# 2zg4iqc1u4MIWzM567B8om    Life Support                    Stained Glass
# 2AxPkyjV7C1gJi0ep3j9wV    Life Support                Emotional Bruises
# 3T7qQEncNHkrBGFbKe2XeG    Life Support  Everything Happens For A Reason
# 406NLtFubTrkwUSq62767y    Life Support        Channel Surfing / The End
# 330CwDQh6mZ9yAWnJ1svDL  As She Pleases                             Dead
# 56PI2B44h5mId3OAMrsM1r  As She Pleases                            Fools
# 3rf9vbMO0vuhtB3CDHTjsO  As She Pleases                        HeartLess
# 6hNnGxiht3UgeVE9eqoN4F  As She Pleases                     Tyler Durden
# 6Z3KPGftGu9ZVvkAY8SaZa  As She Pleases                    Home with You
# 0ozo6xfFvHOxn1o2dA2UPk  As She Pleases                 Teenager in Love
# 27TOMo26A8fEPKTIBf9SNR  As She Pleases                Say It to My Face
#
#                        release_date  popularity duration_ms  acousticness  \
# 27TOMo26A8fEPKTIBf9SNR    0.2760    -4.763     0       0.4350  113.881
#
#                         time_signature  valence
# 0lhDiOviH4xmzyYeOsn01M               3   0.0481
# 4y3g40TWe7fCWCayJZuGvw               4   0.4560
# 5AEJyckUMzLqIyBxZNmGFW               4   0.2400
# 2Txj791OlOaNSMpps0gz5K               4   0.2200
# 6sRmaXQZo0EK2woVn2COxM               4   0.2670
# 6mstsFlnLZidRE8K3JGtV7               4   0.1730
# 4a1RWaG4BTkifgMSx3rpf3               4   0.3460
# 3Fsr7IhlNBZ1wV3QaJB5dv               5   0.2980
# 5QlMftmj7rFwhHoClCQLTP               4   0.3300
# 5UY8jf31X2hJkiAualFTyh               4   0.2330
# 4wz7R8N7gYgjhZuoMQkSve               4   0.4620
# 6XiqdnMk2LLbmybmyx30jD               4   0.5700
# 1X4ZkhlRRohkV33cITaJYs               4   0.4520
# 2zg4iqc1u4MIWzM567B8om               4   0.1300
# 2AxPkyjV7C1gJi0ep3j9wV               3   0.3300
# 3T7qQEncNHkrBGFbKe2XeG               4   0.0760
# 406NLtFubTrkwUSq62767y               3   0.3620
# 330CwDQh6mZ9yAWnJ1svDL               4   0.5530
# 56PI2B44h5mId3OAMrsM1r               4   0.8510
# 3rf9vbMO0vuhtB3CDHTjsO               4   0.2350
# 6hNnGxiht3UgeVE9eqoN4F               4   0.7400
# 6Z3KPGftGu9ZVvkAY8SaZa               4   0.7320
# 0ozo6xfFvHOxn1o2dA2UPk               3   0.5790
# 27TOMo26A8fEPKTIBf9SNR               4   0.5910

# %%
## Just outputting to a CSV so I can experiment in tableau
track_info.to_csv("out2.csv")

# %% [markdown]
# ## Step 4: Repeat Steps 1-3 but for singles
#
# We already put steps 1-3 into functions so this doesn't require much duplicate code at all!
#
# In the future, instead of calling get_albums on albums and singles individually we could call for both at the same time saving on at most 1 API call per artist.
#
# If we go into large scale production and get bottlenecked by rate limits, this could be a good improvement. For now, it's pedantic and not worth the energy to rewrite otherwise working code.

# %% [markdown]
# ### Step 4a: Get singles

# %%
single_list = get_albums('single')
# Out:
# 0
# 1
# Done!

# %% [markdown]
# ### Step 4b: Filter duplicate singles

# %%
filtered_single_ids = filter_duplicates(single_list)
# Out:
# We removed 0 duplicates

# %% [markdown]
# ### Step 4c: Retrieve singles and add if they're unique

# %%
track_ids = get_new_tracks(single_list,filtered_single_ids)
# Out:
# We have a duplicate track name: BOYSHIT
# We have a duplicate track name: Baby
# We have a duplicate track name: Stained Glass
# We have a duplicate track name: Selfish
# We have a duplicate track name: Good In Goodbye
# We have a duplicate track name: Say It to My Face
# We have a duplicate track name: Dead

# %% [markdown]
# ### Step 4d: Retrieve features for these new singles

# %%
get_features(track_ids,track_info)

# %%
track_info
# Out:
#                                                                album_name  \
# 0lhDiOviH4xmzyYeOsn01M                                       Life Support
# 4y3g40TWe7fCWCayJZuGvw                                       Life Support
# 5AEJyckUMzLqIyBxZNmGFW                                       Life Support
# 2Txj791OlOaNSMpps0gz5K                                       Life Support
# 6sRmaXQZo0EK2woVn2COxM                                       Life Support
# 4XvAkYELvcF94Tllzwot19  Dead (Madison Beer vs. Cedric Gervais) [Cedric...
# 2lweusZXHxg30xywFKuoo2            Something Sweet (Exit Friendzone Remix)
# 3PlM3biKS6ZUIHojCJmElE                                    Something Sweet
# 7lqsmY0ifoZsqBU6DpbCIq                                       All For Love
# 2gdSWTbxMeXADbsgWhNgt5                   Unbreakable (Monsieur Adi Remix)
# 39a5hrymfoFgpMxBn3BAPn                                        Unbreakable
# 4jPC5HNBHkuRMtrscdHQty                                           Melodies
#
#                                                                track_name  \
# 0lhDiOviH4xmzyYeOsn01M                                      The Beginning
# 4y3g40TWe7fCWCayJZuGvw                                    Good In Goodbye
# 5AEJyckUMzLqIyBxZNmGFW                                            Default
# 2Txj791OlOaNSMpps0gz5K                            Follow The White Rabbit
# 6sRmaXQZo0EK2woVn2COxM                                       Effortlessly
# 6mstsFlnLZidRE8K3JGtV7                             Stay Numb And Carry On
# 4a1RWaG4BTkifgMSx3rpf3                                               Blue
# 3Fsr7IhlNBZ1wV3QaJB5dv                                          Interlude
# 5QlMftmj7rFwhHoClCQLTP                                           Homesick
# 5UY8jf31X2hJkiAualFTyh                                            Selfish
# 4wz7R8N7gYgjhZuoMQkSve                                         Sour Times
# 6XiqdnMk2LLbmybmyx30jD                                            BOYSHIT
# 1X4ZkhlRRohkV33cITaJYs                                               Baby
# 2zg4iqc1u4MIWzM567B8om                                      Stained Glass
# 2AxPkyjV7C1gJi0ep3j9wV                                  Emotional Bruises
# 3T7qQEncNHkrBGFbKe2XeG                    Everything Happens For A Reason
# 406NLtFubTrkwUSq62767y                          Channel Surfing / The End
# 330CwDQh6mZ9yAWnJ1svDL                                               Dead
# 56PI2B44h5mId3OAMrsM1r                                              Fools
# 3rf9vbMO0vuhtB3CDHTjsO                                          HeartLess
# 6hNnGxiht3UgeVE9eqoN4F                                       Tyler Durden
# 6Z3KPGftGu9ZVvkAY8SaZa                                      Home with You
# 0ozo6xfFvHOxn1o2dA2UPk                                   Teenager in Love
# 27TOMo26A8fEPKTIBf9SNR                                  Say It to My Face
# 5Kq2GzvM6XE8zN4RAKKLSf            Showed Me (How I Fell In Love With You)
# 3DpxSpi0jot0XH73uZmlul                                          Dangerous
# 3Hz0axxTsemGQSNK3BiRa9  I Have Never Felt More Alive - from the featur...
# 5ajjAnNRh8bxFvaVHzpPjh                                           Reckless
# 4IvuPZogXbY7LODs7qzr0W    Carried Away (Love To Love) (with Madison Beer)
# 6juLaduD4STCUDWT0AYun4                                               MORE
# 2foInBCiH2rjKwPoasl0Uc                            Baby - Jonas Blue Remix
# 6ASK46er1mupkMQzHZ2juO                              Baby - Syn Cole Remix
# 5CkILcn5YhXYJ1XDuGwrGN                        Selfish - Alan Walker Remix
# 4gMC0JNQITGa8wfTFsPu3f  All Day And Night - Jax Jones & Martin Solveig...
# 0Es6dDXHGqqQWoA8tlK4LG                                       Dear Society
# 33CfD8UkDEcSdAP9j4QpUY                                  All Day And Night
# 5hSBcKW65qgvRGBHRdsrtT                 Hurts Like Hell - Feenixpawl Remix
# 39a5hrymfoFgpMxBn3BAPn    0.0631    -5.098     1       0.0335  123.012
# 4jPC5HNBHkuRMtrscdHQty    0.5390    -2.695     1       0.2180  178.287
#
#                         time_signature  valence
# 0lhDiOviH4xmzyYeOsn01M               3   0.0481
# 4y3g40TWe7fCWCayJZuGvw               4   0.4560
# 5AEJyckUMzLqIyBxZNmGFW               4   0.2400
# 2Txj791OlOaNSMpps0gz5K               4   0.2200
# 6sRmaXQZo0EK2woVn2COxM               4   0.2670
# 6mstsFlnLZidRE8K3JGtV7               4   0.1730
# 4a1RWaG4BTkifgMSx3rpf3               4   0.3460
# 3Fsr7IhlNBZ1wV3QaJB5dv               5   0.2980
# 5QlMftmj7rFwhHoClCQLTP               4   0.3300
# 5UY8jf31X2hJkiAualFTyh               4   0.2330
# 4wz7R8N7gYgjhZuoMQkSve               4   0.4620
# 6XiqdnMk2LLbmybmyx30jD               4   0.5700
# 1X4ZkhlRRohkV33cITaJYs               4   0.4520
# 2zg4iqc1u4MIWzM567B8om               4   0.1300
# 2AxPkyjV7C1gJi0ep3j9wV               3   0.3300
# 3T7qQEncNHkrBGFbKe2XeG               4   0.0760
# 406NLtFubTrkwUSq62767y               3   0.3620
# 330CwDQh6mZ9yAWnJ1svDL               4   0.5530
# 56PI2B44h5mId3OAMrsM1r               4   0.8510
# 3rf9vbMO0vuhtB3CDHTjsO               4   0.2350
# 6hNnGxiht3UgeVE9eqoN4F               4   0.7400
# 6Z3KPGftGu9ZVvkAY8SaZa               4   0.7320
# 0ozo6xfFvHOxn1o2dA2UPk               3   0.5790
# 27TOMo26A8fEPKTIBf9SNR               4   0.5910
# 5Kq2GzvM6XE8zN4RAKKLSf               4   0.6750
# 3DpxSpi0jot0XH73uZmlul               3   0.1700
# 3Hz0axxTsemGQSNK3BiRa9               4   0.1860
# 5ajjAnNRh8bxFvaVHzpPjh               3   0.2610
# 4IvuPZogXbY7LODs7qzr0W               4   0.3040
# 6juLaduD4STCUDWT0AYun4               4   0.1990
# 2foInBCiH2rjKwPoasl0Uc               4   0.4250
# 6ASK46er1mupkMQzHZ2juO               4   0.7910
# 5CkILcn5YhXYJ1XDuGwrGN               4   0.3100
# 4gMC0JNQITGa8wfTFsPu3f               4   0.2490
# 0Es6dDXHGqqQWoA8tlK4LG               4   0.4160
# 33CfD8UkDEcSdAP9j4QpUY               4   0.5210
# 5hSBcKW65qgvRGBHRdsrtT               4   0.6300
# 0dSKYXx9OUrE6u53o1ChVT               4   0.4160
# 1thsMfc9Z8zztIx7Le3JQM               4   0.6080
# 5sbooPcNgIE22DwO0VNGUJ               4   0.3850
# 2zp7ctncnTAAeX7OvLBOJb               4   0.8960
# 17vnjYJpk8PH58zln5ALur               4   0.2400
# 2vS31cjCmCtYLmsoHDyo2E               4   0.3200
# 2UsVYn7pQkmsSXp8yLmI0b               4   0.7000
# 04CgWOjdaOwYLFscbAZnJz               4   0.2820
# 30WF6XQG9LGeETX9b5COU4               4   0.3500
# 4tW3DyfV0LGucMCRzpIgbY               4   0.3990
# 0wtIQXfaKPFpt2ihDcpcRy               4   0.4690
# 4XvAkYELvcF94Tllzwot19               4   0.4900
# 2lweusZXHxg30xywFKuoo2               4   0.3420
# 3PlM3biKS6ZUIHojCJmElE               4   0.6470
# 7lqsmY0ifoZsqBU6DpbCIq               4   0.1330
# 2gdSWTbxMeXADbsgWhNgt5               4   0.4870
# 39a5hrymfoFgpMxBn3BAPn               4   0.4250
# 4jPC5HNBHkuRMtrscdHQty               4   0.5690

# %% [markdown]
# ### Step 5: Clean and process our data for recommendation
#
# A couple of things to point out.
#
# #### Onehot encoding
#
# We need to onehot encode our data because our similarity metric uses cosine similarity/distance, which does not work with categorical columns.
#
# Some classes that could be encoded but probably shouldn't be: Keys, Pitch Classes, Time Signature.
#
# These features (from Spotify) each have their own basis in numeric space (i.e. distance between Pitch Class 2 and 3 vs 2 and 4 does have mathematical significance) so we leave it as is.
#
# #### Dealing with release date
#
# We could convert release date into Unix time in seconds but I figured a more practical approach would be to instead look at the artists "progress" into their career: whether a song was released at the start or towards their latest release.
#
# Artists, now more than ever, tend to develop and change their sound over time especially with every major album release. Much of this could be attributed to the change from buying songs in records to browsing songs on streaming services but that's a separate rant.
#
# By converting release date into a range of [0,1] we are mapping songs together to account for an artist's growth while still also considering album groupings because album_name is being onehot encoded as well.
#
# Arguably this is overfitting, but in testing it almost seems to not overfit enough.
#
# A large reason for this is because if an artist only started recently, the difference between 0 and 1 is huge, but the difference between 2022 and 2023 isn't as an artist isn't likely to change their sound so drastically in a year.
#
# In the future, one way to deal with this would be to creative a "minimum" of five years to every artist's career so that even if they have only been producing for a year, their release dates get mapped to 0.9 and 1 so they're not as far apart. Currently not needed, but I'm documenting this for myself in case I need to revisit this idea.
#
# ### Removing interludes
#
# Often artists will include interludes in their albums or joke tracks or other songs not worth recommending. These tracks aren't flagged by Spotify in any particular way. We will attempt to find these tracks ourselves by finding extreme statistical outliers using the IQR for song duration.
#
# Interludes will get suggested so rarely that it's significantly more important that we don't over-remove songs than we do remove all interludes.
#
# One suggestion would be to set a song minimum of 30 seconds, but there could be a case where someone's favorite Spotify artist uploads 25 seconds spoken word and we wouldn't want to just delete all of their tracks. That's why we chose to go with the IQR approach with a number of 3.6 instead of the standard 1.5.
#
# For a typical artist this approach will map to around 30 seconds anyways while accounting for the edge cases.

# %%
start = 0

def clean_data(track_info):
    ## In theory we could also get dummies for keys but pitch classes seem to have numeric analogue
    ## Same goes for time_signature
    cleaned = pd.get_dummies(track_info,columns=['album_name','mode'])

    ## Converting release date to a "career" field
    start = track_info['release_date'].min()
    cleaned['career'] = track_info['release_date'] - start
    cleaned['career'] = cleaned['career'].dt.days
    end = cleaned['career'].max()
    cleaned['career'] = cleaned['career'] / end

    ## Finding duration outliers and dropping them!!
    durs = cleaned["duration_ms"]
    Q1 = durs.quantile(0.25)
    Q3 = durs.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 3.6*IQR
    keep = np.array(durs>lower_bound)
    removed_cnt = np.size(keep) - np.count_nonzero(keep)
    cleaned = cleaned.loc[keep]
    if removed_cnt > 0:
        print("We removed " + str(removed_cnt) + " songs based on length")

    ## CHanging loudness from [min,max] to [0,1]
    cleaned["loudness"] = cleaned["loudness"] - cleaned["loudness"].min()
    cleaned["loudness"] = cleaned["loudness"] / cleaned["loudness"].max()

    ## Drop all columns we don't care about anymore
    # cleaned = cleaned.drop(columns=['track_name','popularity','release_date','duration_ms'])
    cleaned = cleaned.drop(columns=['track_name','release_date','duration_ms'])
    return cleaned

cleaned = clean_data(track_info)

# %%
cleaned
# Out:
#                         popularity  acousticness  danceability  energy  \
# 0lhDiOviH4xmzyYeOsn01M         0.0       0.43900         0.262   0.301
# 4y3g40TWe7fCWCayJZuGvw         0.0       0.43300         0.658   0.698
# 5AEJyckUMzLqIyBxZNmGFW         0.0       0.55600         0.143   0.327
# 2Txj791OlOaNSMpps0gz5K         0.0       0.22200         0.650   0.405
# 6sRmaXQZo0EK2woVn2COxM         0.0       0.58400         0.309   0.567
# 6mstsFlnLZidRE8K3JGtV7         0.0       0.21300         0.611   0.580
# 4a1RWaG4BTkifgMSx3rpf3         0.0       0.15000         0.640   0.501
# 3Fsr7IhlNBZ1wV3QaJB5dv         0.0       0.70600         0.390   0.176
# 5QlMftmj7rFwhHoClCQLTP         0.0       0.54600         0.332   0.416
# 5UY8jf31X2hJkiAualFTyh         0.0       0.62700         0.375   0.461
# 4wz7R8N7gYgjhZuoMQkSve         0.0       0.05520         0.646   0.591
# 6XiqdnMk2LLbmybmyx30jD         0.0       0.02030         0.638   0.699
# 1X4ZkhlRRohkV33cITaJYs         0.0       0.07990         0.705   0.707
# 2zg4iqc1u4MIWzM567B8om         0.0       0.30500         0.278   0.605
# 2AxPkyjV7C1gJi0ep3j9wV         0.0       0.18200         0.522   0.577
# 3T7qQEncNHkrBGFbKe2XeG         0.0       0.18400         0.247   0.482
# 406NLtFubTrkwUSq62767y         0.0       0.87600         0.323   0.684
# 330CwDQh6mZ9yAWnJ1svDL         0.0       0.40000         0.597   0.700
# 56PI2B44h5mId3OAMrsM1r         0.0       0.02800         0.743   0.793
# 3rf9vbMO0vuhtB3CDHTjsO         0.0       0.21100         0.636   0.439
# 6hNnGxiht3UgeVE9eqoN4F         0.0       0.82900         0.658   0.258
# 6Z3KPGftGu9ZVvkAY8SaZa         0.0       0.06460         0.631   0.600
# 0ozo6xfFvHOxn1o2dA2UPk         0.0       0.30100         0.673   0.578
# 27TOMo26A8fEPKTIBf9SNR         0.0       0.16900         0.753   0.566
# 5Kq2GzvM6XE8zN4RAKKLSf         0.0       0.47600         0.723   0.542
# 3DpxSpi0jot0XH73uZmlul         0.0       0.87400         0.351   0.355
# 3Hz0axxTsemGQSNK3BiRa9         0.0       0.21800         0.560   0.627
# 5ajjAnNRh8bxFvaVHzpPjh         0.0       0.80700         0.386   0.426
# 4IvuPZogXbY7LODs7qzr0W         0.0       0.34600         0.518   0.683
# 6juLaduD4STCUDWT0AYun4         0.0       0.00257         0.660   0.787
# 2foInBCiH2rjKwPoasl0Uc         0.0       0.01920         0.708   0.817
# 6ASK46er1mupkMQzHZ2juO         0.0       0.07760         0.765   0.803
# 3PlM3biKS6ZUIHojCJmElE          0.000003   9.0    0.2450  0.704714
# 7lqsmY0ifoZsqBU6DpbCIq          0.000038   1.0    0.0658  0.717185
# 2gdSWTbxMeXADbsgWhNgt5          0.104000   7.0    0.1500  0.677764
# 39a5hrymfoFgpMxBn3BAPn          0.000000   7.0    0.0631  0.695413
# 4jPC5HNBHkuRMtrscdHQty          0.000000   6.0    0.5390  0.949376
#
#                         speechiness    tempo  ...  \
# 0lhDiOviH4xmzyYeOsn01M       0.0335  102.399  ...
# 4y3g40TWe7fCWCayJZuGvw       0.1770  139.054  ...
# 5AEJyckUMzLqIyBxZNmGFW       0.0327  187.194  ...
# 2Txj791OlOaNSMpps0gz5K       0.0329   95.005  ...
# 6sRmaXQZo0EK2woVn2COxM       0.0498   75.276  ...
# 6mstsFlnLZidRE8K3JGtV7       0.0355   92.489  ...
# 4a1RWaG4BTkifgMSx3rpf3       0.0624  114.031  ...
# 3Fsr7IhlNBZ1wV3QaJB5dv       0.0485   90.857  ...
# 5QlMftmj7rFwhHoClCQLTP       0.0326   81.198  ...
# 5UY8jf31X2hJkiAualFTyh       0.0279   75.217  ...
# 4wz7R8N7gYgjhZuoMQkSve       0.3080  165.029  ...
# 6XiqdnMk2LLbmybmyx30jD       0.0892  121.122  ...
# 1X4ZkhlRRohkV33cITaJYs       0.0534  117.974  ...
# 2zg4iqc1u4MIWzM567B8om       0.0479   84.874  ...
# 2AxPkyjV7C1gJi0ep3j9wV       0.0761  173.174  ...
# 3T7qQEncNHkrBGFbKe2XeG       0.0308   88.132  ...
# 406NLtFubTrkwUSq62767y       0.3010  184.697  ...
# 330CwDQh6mZ9yAWnJ1svDL       0.1920  103.209  ...
# 56PI2B44h5mId3OAMrsM1r       0.0388  120.897  ...
# 3rf9vbMO0vuhtB3CDHTjsO       0.0303  100.046  ...
# 6hNnGxiht3UgeVE9eqoN4F       0.0356  119.987  ...
# 6Z3KPGftGu9ZVvkAY8SaZa       0.0873  170.128  ...
# 0ozo6xfFvHOxn1o2dA2UPk       0.0278  109.979  ...
# 27TOMo26A8fEPKTIBf9SNR       0.4350  113.881  ...
# 5Kq2GzvM6XE8zN4RAKKLSf       0.0260   95.020  ...
# 3DpxSpi0jot0XH73uZmlul       0.0286   77.248  ...
# 3Hz0axxTsemGQSNK3BiRa9       0.0393  112.015  ...
# 5ajjAnNRh8bxFvaVHzpPjh       0.0363  180.104  ...
# 4IvuPZogXbY7LODs7qzr0W       0.0364  141.971  ...
# 6juLaduD4STCUDWT0AYun4       0.0320  142.018  ...
# 2foInBCiH2rjKwPoasl0Uc       0.0372  123.005  ...
# 6ASK46er1mupkMQzHZ2juO       0.0533  121.964  ...
# 5CkILcn5YhXYJ1XDuGwrGN       0.0471  157.838  ...
# 4gMC0JNQITGa8wfTFsPu3f       0.0399  125.004  ...
# 0Es6dDXHGqqQWoA8tlK4LG       0.0491  145.942  ...
# 33CfD8UkDEcSdAP9j4QpUY       0.0897  121.908  ...
# 5hSBcKW65qgvRGBHRdsrtT       0.0574  128.951  ...
# 0dSKYXx9OUrE6u53o1ChVT       0.0479   72.163  ...
# 1thsMfc9Z8zztIx7Le3JQM       0.1790   75.002  ...
# 5sbooPcNgIE22DwO0VNGUJ       0.0872  170.036  ...
# 2zp7ctncnTAAeX7OvLBOJb       0.0417  124.014  ...
# 17vnjYJpk8PH58zln5ALur       0.0915   85.061  ...
# 2vS31cjCmCtYLmsoHDyo2E       0.0398  124.937  ...
# 2UsVYn7pQkmsSXp8yLmI0b       0.0538  124.988  ...
# 04CgWOjdaOwYLFscbAZnJz       0.0569  122.956  ...
# 30WF6XQG9LGeETX9b5COU4       0.0657  122.989  ...
# 4tW3DyfV0LGucMCRzpIgbY       0.0464  122.975  ...
# 0wtIQXfaKPFpt2ihDcpcRy       0.0300   92.106  ...
# 4XvAkYELvcF94Tllzwot19       0.0972  102.934  ...
# 2lweusZXHxg30xywFKuoo2       0.0406   99.388  ...
# 3PlM3biKS6ZUIHojCJmElE       0.0377   99.979  ...
# 7lqsmY0ifoZsqBU6DpbCIq       0.0556  119.905  ...
# 2gdSWTbxMeXADbsgWhNgt5       0.0500  122.969  ...
# 39a5hrymfoFgpMxBn3BAPn       0.0335  123.012  ...
# 4jPC5HNBHkuRMtrscdHQty       0.2180  178.287  ...
#
#                         album_name_Say It to My Face (The Wideboys Remix)  \
# 0lhDiOviH4xmzyYeOsn01M                                                  0
# 4y3g40TWe7fCWCayJZuGvw                                                  0
# 5AEJyckUMzLqIyBxZNmGFW                                                  0
# 2Txj791OlOaNSMpps0gz5K                                                  0
# 6sRmaXQZo0EK2woVn2COxM                                                  0
# 6mstsFlnLZidRE8K3JGtV7                                                  0
# 4a1RWaG4BTkifgMSx3rpf3                                                  0
# 3Fsr7IhlNBZ1wV3QaJB5dv                                                  0
# 5QlMftmj7rFwhHoClCQLTP                                                  0
# 5UY8jf31X2hJkiAualFTyh                                                  0
# 4wz7R8N7gYgjhZuoMQkSve                                                  0
# 6XiqdnMk2LLbmybmyx30jD                                                  0
# 1X4ZkhlRRohkV33cITaJYs                                                  0
# 2zg4iqc1u4MIWzM567B8om                                                  0
# 2AxPkyjV7C1gJi0ep3j9wV                                                  0
# 3T7qQEncNHkrBGFbKe2XeG                                                  0
# 406NLtFubTrkwUSq62767y                                                  0
# 330CwDQh6mZ9yAWnJ1svDL                                                  0
# 56PI2B44h5mId3OAMrsM1r                                                  0
# 3rf9vbMO0vuhtB3CDHTjsO                                                  0
# 6hNnGxiht3UgeVE9eqoN4F                                                  0
# 6Z3KPGftGu9ZVvkAY8SaZa                                                  0
# 0ozo6xfFvHOxn1o2dA2UPk                                                  0
# 27TOMo26A8fEPKTIBf9SNR                                                  0
# 5Kq2GzvM6XE8zN4RAKKLSf                                                  0
# 3DpxSpi0jot0XH73uZmlul                                                  0
# 3Hz0axxTsemGQSNK3BiRa9                                                  0
# 5ajjAnNRh8bxFvaVHzpPjh                                                  0
# 4IvuPZogXbY7LODs7qzr0W                                                  0
# 6juLaduD4STCUDWT0AYun4                                                  0
# 2foInBCiH2rjKwPoasl0Uc                                                  0
# 2foInBCiH2rjKwPoasl0Uc                                            0       1
# 6ASK46er1mupkMQzHZ2juO                                            0       0
# 5CkILcn5YhXYJ1XDuGwrGN                                            0       0
# 4gMC0JNQITGa8wfTFsPu3f                                            0       0
# 0Es6dDXHGqqQWoA8tlK4LG                                            0       1
# 33CfD8UkDEcSdAP9j4QpUY                                            0       1
# 5hSBcKW65qgvRGBHRdsrtT                                            0       1
# 0dSKYXx9OUrE6u53o1ChVT                                            0       1
# 1thsMfc9Z8zztIx7Le3JQM                                            0       1
# 5sbooPcNgIE22DwO0VNGUJ                                            0       0
# 2zp7ctncnTAAeX7OvLBOJb                                            0       1
# 17vnjYJpk8PH58zln5ALur                                            0       1
# 2vS31cjCmCtYLmsoHDyo2E                                            0       1
# 2UsVYn7pQkmsSXp8yLmI0b                                            0       1
# 04CgWOjdaOwYLFscbAZnJz                                            0       1
# 30WF6XQG9LGeETX9b5COU4                                            0       1
# 4tW3DyfV0LGucMCRzpIgbY                                            0       1
# 0wtIQXfaKPFpt2ihDcpcRy                                            0       0
# 4XvAkYELvcF94Tllzwot19                                            0       0
# 2lweusZXHxg30xywFKuoo2                                            0       1
# 3PlM3biKS6ZUIHojCJmElE                                            0       1
# 7lqsmY0ifoZsqBU6DpbCIq                                            0       1
# 2gdSWTbxMeXADbsgWhNgt5                                            1       0
# 39a5hrymfoFgpMxBn3BAPn                                            0       0
# 4jPC5HNBHkuRMtrscdHQty                                            0       0
#
#                         mode_1    career
# 0lhDiOviH4xmzyYeOsn01M       1  0.833707
# 4y3g40TWe7fCWCayJZuGvw       0  0.833707
# 5AEJyckUMzLqIyBxZNmGFW       0  0.833707
# 2Txj791OlOaNSMpps0gz5K       1  0.833707
# 6sRmaXQZo0EK2woVn2COxM       0  0.833707
# 6mstsFlnLZidRE8K3JGtV7       0  0.833707
# 4a1RWaG4BTkifgMSx3rpf3       1  0.833707
# 3Fsr7IhlNBZ1wV3QaJB5dv       1  0.833707
# 5QlMftmj7rFwhHoClCQLTP       1  0.833707
# 5UY8jf31X2hJkiAualFTyh       1  0.833707
# 4wz7R8N7gYgjhZuoMQkSve       1  0.833707
# 6XiqdnMk2LLbmybmyx30jD       1  0.833707
# 1X4ZkhlRRohkV33cITaJYs       1  0.833707
# 2zg4iqc1u4MIWzM567B8om       1  0.833707
# 2AxPkyjV7C1gJi0ep3j9wV       1  0.833707
# 3T7qQEncNHkrBGFbKe2XeG       1  0.833707
# 406NLtFubTrkwUSq62767y       1  0.833707
# 330CwDQh6mZ9yAWnJ1svDL       0  0.520157
# 56PI2B44h5mId3OAMrsM1r       0  0.520157
# 3rf9vbMO0vuhtB3CDHTjsO       0  0.520157
# 6hNnGxiht3UgeVE9eqoN4F       1  0.520157
# 6Z3KPGftGu9ZVvkAY8SaZa       0  0.520157
# 0ozo6xfFvHOxn1o2dA2UPk       1  0.520157
# 27TOMo26A8fEPKTIBf9SNR       0  0.520157
# 5Kq2GzvM6XE8zN4RAKKLSf       0  1.000000
# 3DpxSpi0jot0XH73uZmlul       1  0.986562
# 3Hz0axxTsemGQSNK3BiRa9       0  0.976764
# 5ajjAnNRh8bxFvaVHzpPjh       1  0.861142
# 4IvuPZogXbY7LODs7qzr0W       1  0.829787
# 6juLaduD4STCUDWT0AYun4       0  0.799832
# 2foInBCiH2rjKwPoasl0Uc       0  0.796473
# 6ASK46er1mupkMQzHZ2juO       1  0.792553
# 5CkILcn5YhXYJ1XDuGwrGN       1  0.757279
# 4gMC0JNQITGa8wfTFsPu3f       1  0.663214
# 0Es6dDXHGqqQWoA8tlK4LG       0  0.651456
# 33CfD8UkDEcSdAP9j4QpUY       0  0.637458
# 5hSBcKW65qgvRGBHRdsrtT       0  0.631299
# 0dSKYXx9OUrE6u53o1ChVT       0  0.618141
# 1thsMfc9Z8zztIx7Le3JQM       0  0.598544
# 5sbooPcNgIE22DwO0VNGUJ       1  0.596865
# 2zp7ctncnTAAeX7OvLBOJb       0  0.565230
# 17vnjYJpk8PH58zln5ALur       0  0.565230
# 2vS31cjCmCtYLmsoHDyo2E       0  0.510358
# 2UsVYn7pQkmsSXp8yLmI0b       0  0.510358
# 04CgWOjdaOwYLFscbAZnJz       0  0.506439
# 30WF6XQG9LGeETX9b5COU4       0  0.506439
# 4tW3DyfV0LGucMCRzpIgbY       0  0.506439
# 0wtIQXfaKPFpt2ihDcpcRy       1  0.475084
# 4XvAkYELvcF94Tllzwot19       1  0.471165
# 2lweusZXHxg30xywFKuoo2       0  0.345465
# 3PlM3biKS6ZUIHojCJmElE       0  0.302632
# 7lqsmY0ifoZsqBU6DpbCIq       0  0.273236
# 2gdSWTbxMeXADbsgWhNgt5       1  0.162654
# 39a5hrymfoFgpMxBn3BAPn       1  0.148936
# 4jPC5HNBHkuRMtrscdHQty       1  0.000000
#
# [55 rows x 44 columns]

# %% [markdown]
# ## Step 6: Get a seed song and define our likeability metric
#
# How do we pick the first song to recommend? Picking the most popular one is probably a safe bet - it's popular for a reason!

# %% [markdown]
# ### Step 6a: Get most popular song for seed song
#
# This code will break if none of their most popular songs are in our database.
#
# This would only happen if all of their most popular songs are by another artist, which I haven't seen yet but let's be honest if that's the case you probably shouldn't listen to them anyways.
#
# It's really easy to just pick a random seed song instead, but I think this approach is significantly funnier.

# %%
## Get most popular tracks
r = requests.get(BASE_URL + 'artists/' + global_artist_id + '/top-tracks',headers=headers,params={'market':'US'})
trracks = r.json()['tracks']
still_searching = True
## As we iterate over tracks, get their popularity metrics
for track in trracks:
    most_id = track["id"]
    ## Record the popularity IF it's in the index
    if most_id in cleaned.index:
        pop = track.get("popularity",0)
        cleaned.loc[most_id,"popularity"] = pop/100
        ## If we still need a seed song, write it down
        if still_searching:
            most_pop = cleaned.loc[most_id].to_frame().transpose()
            still_searching = False
if still_searching:
    raise Exception("This artist stinks we couldn't find a single song of theirs that was popular to suggest")
most_pop
# Out:
#                         popularity  acousticness  danceability  energy  \
# 5ajjAnNRh8bxFvaVHzpPjh        0.81         0.807         0.386   0.426
#
#                         instrumentalness  key  liveness  loudness  \
# 5ajjAnNRh8bxFvaVHzpPjh               0.0  3.0      0.14  0.532234
#
#                         speechiness    tempo  ...  \
# 5ajjAnNRh8bxFvaVHzpPjh       0.0363  180.104  ...
#
#                         album_name_Say It to My Face (The Wideboys Remix)  \
# 5ajjAnNRh8bxFvaVHzpPjh                                                0.0
#
#                         album_name_Selfish (Alan Walker Remix)  \
# 5ajjAnNRh8bxFvaVHzpPjh                                     0.0
#
#                         album_name_Showed Me (How I Fell In Love With You)  \
# 5ajjAnNRh8bxFvaVHzpPjh                                                0.0
#
#                         album_name_Something Sweet  \
# 5ajjAnNRh8bxFvaVHzpPjh                         0.0
#
#                         album_name_Something Sweet (Exit Friendzone Remix)  \
# 5ajjAnNRh8bxFvaVHzpPjh                                                0.0
#
#                         album_name_Unbreakable  \
# 5ajjAnNRh8bxFvaVHzpPjh                     0.0
#
#                         album_name_Unbreakable (Monsieur Adi Remix)  mode_0  \
# 5ajjAnNRh8bxFvaVHzpPjh                                          0.0     0.0
#
#                         mode_1    career
# 5ajjAnNRh8bxFvaVHzpPjh     1.0  0.861142
#
# [1 rows x 44 columns]

# %% [markdown]
# ### Step 7: Start computing distances
#
# I'll create a video explaining why we're using this metric.

# %%
(r,_) = track_info.shape
prev = np.ones((r,1))

## Store track_ids of songs already recommended
viewed_tracks = []

def get_song_recommendation(stripped,new_track_info,liked=True):
    global prev
    ## Step 0: Mark this track as viewed
    prev_id = new_track_info.index[0]
    viewed_tracks.append(prev_id)
    ## Step 1: Get distances from new track
    dists = cosine_similarity(stripped,new_track_info)
    ## Step 2: If we hated that song, we want songs that are far away from it
    if not liked:
        dists = 1 - dists
    ## Step 3: Get new metric array
    prev = np.multiply(prev,dists)
    ## Step 4: From this array, get next song to recommend
    sortedd = np.argsort(prev,axis=0)
    for ii in range(1,20):
        jj = sortedd[-ii][0]
        new_track_id = stripped.iloc[jj].name
        if new_track_id not in viewed_tracks:
            return stripped.iloc[jj].to_frame().transpose()

# %% [markdown]
# ### Step 8: Start recommending songs and hearing back!

# %%
from time import sleep

new_rec = most_pop
for _ in range(5):
    new_rec_id = new_rec.index[0]
    new_rec_name = track_info.loc[new_rec_id,"track_name"]
    print("You should check out " + new_rec_name + " (spotify:track:" + new_rec_id + ")")
    sleep(1)
    enjoyed = input("Did you enjoy this track? Yes or No")
    print("Did you enjoy this track? " + enjoyed)
    if enjoyed == "Yes":
        new_rec = get_song_recommendation(cleaned,new_rec,True)
    else:
        new_rec = get_song_recommendation(cleaned,new_rec,False)
# Out:
# You should check out Reckless (spotify:track:5ajjAnNRh8bxFvaVHzpPjh)
# Did you enjoy this track? Yes
# You should check out Carried Away (Love To Love) (with Madison Beer) (spotify:track:4IvuPZogXbY7LODs7qzr0W)
# Did you enjoy this track? Yes
# You should check out Sour Times (spotify:track:4wz7R8N7gYgjhZuoMQkSve)
# Did you enjoy this track? Yes
# You should check out BOYSHIT (spotify:track:6XiqdnMk2LLbmybmyx30jD)
# Did you enjoy this track? Yes
# You should check out MORE (spotify:track:6juLaduD4STCUDWT0AYun4)
# Did you enjoy this track? No
